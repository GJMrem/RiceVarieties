# %%
#import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Rescaling
from keras.losses import SparseCategoricalCrossentropy
from keras.optimizers import adam_v2
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.preprocessing.image import image_dataset_from_directory

# %%
physical_devices = tf.config.list_physical_devices()
physical_devices
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
#tf.config.experimental.set_memory_growth(physical_devices[0], True)

# %%
batch_size=16
image_size=(250, 250)

# %%
train_ds = image_dataset_from_directory(
    'Rice_Image_Dataset',
    color_mode='grayscale',
    shuffle = True,
    subset='training',
    validation_split=0.2,
    seed=42,                 
    batch_size=batch_size,
    image_size=image_size
)

val_ds = image_dataset_from_directory(
    'Rice_Image_Dataset',
    color_mode='grayscale',
    shuffle = True,
    subset='validation',
    validation_split=0.2,
    seed=42,                 
    batch_size=batch_size,
    image_size=image_size
)
# Out:
# Found 75000 files belonging to 5 classes.
# Using 60000 files for training.
# Found 75000 files belonging to 5 classes.
# Using 15000 files for validation.

# %%
class_names = train_ds.class_names
class_names
# Out:
# ['Arborio', 'Basmati', 'Ipsala', 'Jasmine', 'Karacadag']

# %%
plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy())
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
num_classes = len(class_names)

model = Sequential([
  Rescaling(1./255, input_shape=(image_size[0],image_size[1], 1)),
  Conv2D(16, 3, padding='same', activation='relu'),
  MaxPooling2D((2, 2), strides=2),
  Conv2D(32, 3, padding='same', activation='relu'),
  MaxPooling2D((2, 2), strides=2),
  Flatten(),
  Dense(32, activation='relu'),
  Dense(num_classes, activation='softmax')
])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling (Rescaling)        (None, 250, 250, 1)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 250, 250, 16)      160
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 125, 125, 16)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 125, 125, 32)      4640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 62, 62, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 123008)            0
# _________________________________________________________________
# dense (Dense)                (None, 32)                3936288
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 165
# =================================================================
# Total params: 3,941,253
# Trainable params: 3,941,253
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(
    optimizer=adam_v2.Adam(learning_rate=0.01),
    loss=SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)

early_stopping = EarlyStopping(
    patience=8,
    monitor='val_accuracy',
    min_delta=1e-4,
    restore_best_weights=True,
)

model_checkpoint = ModelCheckpoint(
    'models/Rice-CNN.hdf5',
    monitor='val_accuracy',
    save_best_only=True
)

# %%
epochs=50
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs,
  steps_per_epoch=75,
  callbacks=[early_stopping, model_checkpoint]
)
# Out:
# Epoch 1/50
# 75/75 [==============================] - 333s 4s/step - loss: 1.0094 - accuracy: 0.6467 - val_loss: 0.2830 - val_accuracy: 0.9005
# Epoch 2/50
# 75/75 [==============================] - 171s 2s/step - loss: 0.3180 - accuracy: 0.9117 - val_loss: 0.2606 - val_accuracy: 0.9049
# Epoch 3/50
# 75/75 [==============================] - 171s 2s/step - loss: 0.8008 - accuracy: 0.8508 - val_loss: 0.2011 - val_accuracy: 0.9339
# Epoch 4/50
# 75/75 [==============================] - 157s 2s/step - loss: 0.2891 - accuracy: 0.9108 - val_loss: 0.1983 - val_accuracy: 0.9355
# Epoch 5/50
# 75/75 [==============================] - 153s 2s/step - loss: 0.2092 - accuracy: 0.9375 - val_loss: 0.1311 - val_accuracy: 0.9567
# Epoch 6/50
# 75/75 [==============================] - 151s 2s/step - loss: 0.1534 - accuracy: 0.9533 - val_loss: 0.1249 - val_accuracy: 0.9581
# Epoch 7/50
# 75/75 [==============================] - 150s 2s/step - loss: 0.1494 - accuracy: 0.9508 - val_loss: 0.1344 - val_accuracy: 0.9563
# Epoch 8/50
# 75/75 [==============================] - 157s 2s/step - loss: 0.1351 - accuracy: 0.9583 - val_loss: 0.1320 - val_accuracy: 0.9581
# Epoch 9/50
# 75/75 [==============================] - 161s 2s/step - loss: 0.1221 - accuracy: 0.9600 - val_loss: 0.1484 - val_accuracy: 0.9493
# Epoch 10/50
# 75/75 [==============================] - 162s 2s/step - loss: 0.1352 - accuracy: 0.9508 - val_loss: 0.1458 - val_accuracy: 0.9495
# Epoch 11/50
# 75/75 [==============================] - 164s 2s/step - loss: 0.1524 - accuracy: 0.9508 - val_loss: 0.1147 - val_accuracy: 0.9637
# Epoch 12/50
# 75/75 [==============================] - 140s 2s/step - loss: 0.0970 - accuracy: 0.9625 - val_loss: 0.1196 - val_accuracy: 0.9641
# Epoch 13/50
# 75/75 [==============================] - 139s 2s/step - loss: 0.1386 - accuracy: 0.9542 - val_loss: 0.1158 - val_accuracy: 0.9613
# Epoch 14/50
# 75/75 [==============================] - 146s 2s/step - loss: 0.1199 - accuracy: 0.9592 - val_loss: 0.1067 - val_accuracy: 0.9637
# Epoch 15/50
# 75/75 [==============================] - 148s 2s/step - loss: 0.1353 - accuracy: 0.9525 - val_loss: 0.1265 - val_accuracy: 0.9579
# Epoch 16/50
# 75/75 [==============================] - 142s 2s/step - loss: 0.1071 - accuracy: 0.9667 - val_loss: 0.1149 - val_accuracy: 0.9617
# Epoch 17/50
# 75/75 [==============================] - 160s 2s/step - loss: 0.1575 - accuracy: 0.9525 - val_loss: 0.1321 - val_accuracy: 0.9527
# Epoch 18/50
# 75/75 [==============================] - 136s 2s/step - loss: 0.1362 - accuracy: 0.9550 - val_loss: 0.1067 - val_accuracy: 0.9633
# Epoch 19/50
# 75/75 [==============================] - 136s 2s/step - loss: 0.1187 - accuracy: 0.9542 - val_loss: 0.1332 - val_accuracy: 0.9547
# Epoch 20/50
# 75/75 [==============================] - 140s 2s/step - loss: 0.1287 - accuracy: 0.9558 - val_loss: 0.1255 - val_accuracy: 0.9564

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(len(history.history['loss']))

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
